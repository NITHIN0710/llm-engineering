# %% [markdown]
# **Tokenizing with Code**

# %%
import tiktoken

encoding = tiktoken.encoding_for_model("gpt-4.1-mini")
tokens = encoding.encode("Hi! My name is Nithin.")

# %%
print(tokens)
# Out:
# [12194, 0, 3673, 1308, 382, 478, 437, 258, 13]

# %%
for token_id in tokens:
    token_text = encoding.decode([token_id])
    print(f"{token_id} = {token_text}")
# Out:
# 12194 = Hi
# 0 = !
# 3673 =  My
# 1308 =  name
# 382 =  is
# 478 =  N
# 437 = ith
# 258 = in
# 13 = .

# %%
encoding.decode([11])
# Out:
# ','

# %% [markdown]
# *The Illusion of Memory*

# %%
import os
from dotenv import load_dotenv

# %%
load_dotenv(override=True)

GEMINI_BASE_URL = "https://generativelanguage.googleapis.com/v1beta/openai/"
api_key = os.getenv('GEMINI_API_KEY')

if not api_key:
    print("No API key is found!")
elif not api_key.startswith("AIz"):
    print("API key is found but it doesn't start with AIz.")
elif api_key.strip() != api_key:
    print("API key is found but it may have spaces at start or end.")
else:
    print("API key is found and Good to Go!")
# Out:
# API key is found and Good to Go!

# %%
from openai import OpenAI
from IPython.display import Markdown, display

gemini = OpenAI(base_url=GEMINI_BASE_URL, api_key=api_key)

# %%
def get_messages():
    prompt = input("Ask anything..")
    return [
        {"role":"system", "content":"You are a helpful assistant"},
        {"role":"user","content":prompt}
    ]

# %%
response = gemini.chat.completions.create(model='gemini-2.5-flash', messages=get_messages())
result = response.choices[0].message.content
display(Markdown(result))
# Out:
# I'm sorry, I don't know your name! As an AI, I don't have access to your personal information or any memory of past conversations unless you've told me your name specifically in this current interaction.
#
# You'll have to tell me!

# %%
messages = [
    {"role": "system", "content": "You are a helpful assistant"},
    {"role": "user", "content": "Hi! I'm Nithin!"},
    {"role": "assistant", "content": "Hi Nithin! How can I assist you today?"},
    {"role": "user", "content": "What's my name?"}
    ]

# %%
response = gemini.chat.completions.create(model='gemini-2.5-flash', messages=messages)
result = response.choices[0].message.content
display(Markdown(result))
# Out:
# Your name is Nithin!
